# %% [markdown]
# <!-- ## O Danych
#
# Dane o pasażerach Titanica
#
# Zbiór danych zawiera informacje o pasażerach RMS Titanic, który zatonął 15 kwietnia 1912 roku po zderzeniu z górą
# lodową. Dane obejmują takie atrybuty jak klasa podróży, wiek, płeć, liczba rodzeństwa/małżonków na pokładzie,
# liczba rodziców/dzieci na pokładzie, cena biletu oraz miejsce zaokrętowania.
#
# Zbiór zawiera także informację o tym, czy pasażer przeżył katastrofę.
#
# Titanic przewoził ponad 2,200 osób, z czego ponad 1,500 zginęło, co czyni tę katastrofę jedną z najbardziej
# tragicznych w historii morskiej.
#
# Kolumny:
#
# * **pclass** - Klasa biletu
# * **survived** - Czy pasażer przeżył katastrofę
# * **name** - Imię i nazwisko pasażera
# * **sex** - Płeć pasażera
# * **age** - Wiek pasażera
# * **sibsp** - Liczba rodzeństwa/małżonków na pokładzie
# * **parch** - Liczba rodziców/dzieci na pokładzie
# * **ticket** - Numer biletu
# * **fare** - Cena biletu
# * **cabin** - Numer kabiny
# * **embarked** - Port, w którym pasażer wszedł na pokład (C = Cherbourg, Q = Queenstown, S = Southampton)
# * **boat** - Numer łodzi ratunkowej
# * **body** - Numer ciała (jeśli pasażer nie przeżył i ciało zostało odnalezione)
# * **home.dest** - Miejsce docelowe -->

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # O danych
# Analiza opiera się na historycznym zbiorze danych pasażerów RMS Titanic, który zatonął 15 kwietnia 1912 roku po zderzeniu z górą lodową. Zbiór zawiera informacje demograficzne i podróżne, takie jak wiek, płeć, klasa biletu, relacje rodzinne na pokładzie, cena biletu czy miejsce zaokrętowania. Kluczową zmienną jest informacja, czy pasażer przeżył katastrofę. W sumie Titanic przewoził ponad 2200 osób, z czego ponad 1500 zginęło, co czyni tę tragedię jedną z najpoważniejszych w historii żeglugi.

# %%
df = pd.read_csv('titanic.csv', sep=",")

# %% [markdown]
# # Eksploracyjna analiza danych na temat katastrofy Tytanica

# %% [markdown]
# ## 1. Wstępna analiza danych

# %% [markdown]
# ### 1. Podstawowe informacje o danych

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %% [markdown]
# ### 2. Zobaczmy podsumowanie wszystkich kolumn numerycznych

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# - Możemy zaobserwować, że średnia cena za bilet wynosiła 33,3 dolary
# - Możemy poweidze, że kolumna survived nie ma tu sensu, gdyż 1 oznacza że osoba przeżyła, a 0, że zginęła, a NaN, że niewiadomo
# - widzimy też, że na 1 pasarzera średnio przypadało 0,5 rodzeństwa i 0,39 rodzica czyli nie było wiele dzieci w porównoiu do inych pasarzerów

# %% [markdown]
# ## 2. Szukamy duplikatów i brakujących wartości

# %%
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %% [markdown]
# Widzimy, że brakuje wiele informacji o:
# - wieku pasażerów,
# - numerów kabin,
# - numerów ciał, dużo pażerów ciał nie odnaleziono, a także niektórzy przeżyli
# - łodzi ratunkowych, dlatego że wielu pasażerów nie byo w łodziach i nie przeżyło
# - końcowych destynacji

# %% [markdown]
# ### 2. Szukamy duplikatów

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Brak duplikatów

# %% [markdown]
# ## 3. Naprawimy kolumny z brakującymi wartościami

# %% [markdown]
# ### 1. Tworzymy dataframe, gdzie brakujace wartości wieku uzupełniamy średnią wieku z danej klasy, a brakujące wartości opłaty za bilet medianą z danej klasy

# %%
drop_age_df=df.dropna(subset="age")
# df=df_aged_droped.dropna(subset="age")

# %%
df["age"] = df["age"].fillna(df.groupby("pclass")["age"].transform("mean"))
df["fare"] = df["fare"].fillna(df.groupby("pclass")["fare"].transform("median"))
# df=df.dropna()

# %% [markdown]
# ### 2. Możemy stworzyć Data frame wyrzucimy wiersze z brakującą płcią

# %%
df = df.dropna(subset=["sex"])

# %% [markdown]
# ## 4. Analizujemy poszczególne kolumny

# %% [markdown]
# ### 1. Przeanalizujmy ile było na pokładzie ludzi rozróżniając ich płci

# %%
sex_count=df["sex"].value_counts()

df_sex_grouped=(df.groupby("sex").agg(
    sum_sex=("sex", "value_counts")
)).reset_index()

df_sex_grouped["sex"] = df_sex_grouped["sex"].replace({
    "female": "Kobiety",
    "male": "Mężczyżni"
})

# %%
# df_sex_grouped

# %%
fig, ax=plt.subplots(1,2, figsize=(7,3))

color=sns.color_palette("colorblind6")
ax[0].bar(df_sex_grouped["sex"],df_sex_grouped["sum_sex"], color=["blue", "orange"]);
ax[0].set_title("Wykres ilości mężczyzn i kobiet na pokładzie")
ax[0].set_ylabel("Ilość pasażerów");

# sex_count.plot(kind="pie",autopct='%1.1f%%', labels=[], data=);
ax[1].pie(x="sum_sex", labels="sex",autopct='%1.1f%%', data=df_sex_grouped);

# %% [markdown]
# Widzimy, że na pokładzie znajdowało się **dużo więcej** mężczyzn niż kobiet, a dokładniej mężczyźni stanowili `64,4%`pasażerów a kobiety `35,6%`

# %% [markdown]
# ### 2. Sprawdzamy ile było kobiet i ile mężczyzn w poszczególnych klasach

# %%
pclass_gruped_sex_df=(df.groupby("pclass").agg(
    sex_count=("sex", "value_counts")
).reset_index())
# pclass_gruped_sex_df

# %%
sns.barplot(x="pclass", y="sex_count", hue="sex", data=pclass_gruped_sex_df);
plt.title("Wykrse pokazujący ilość kobiet i mężczyzn w każdej klasie");
plt.ylabel("ilość osób");
plt.xlabel("Klasy");

# %% [markdown]
# Możemy zaobserwować, że:
# - w klasie 1 była podobna ilość mężczyzn i kobiet i wynosiła od `160 do 180`
# - w klasie 2 większość stanowili mężczyźni było ich `ok 160`, a kobiet `około 110`
# - w klasie 3 natomiast ogromną większość stanowili mężczyźni było `ich około 500`, natomiast kobiet było `200`

# %% [markdown]
# ### 3. Sprawdżmy dane dotyczące cen bletów w poszczególnych klasach

# %%
classs_1_df=df[df["pclass"]==1]
# zmienna przechowująca dane tabelarycze 1 klasy

classs_2_df=df[df["pclass"]==2]
# zmienna przechowująca dane tabelarycze 2 klasy

classs_3_df=df[df["pclass"]==3]
# zmienna przechowująca dane tabelarycze 3 klasy

# %%
pclass_gruped_ticket_fare_df=df.groupby("pclass").agg({
    "fare":["mean","median","max","min",]
})
pclass_gruped_ticket_fare_df
# Out:
#              fare
#              mean   median       max  min
# pclass
# 1.0     87.508992  60.0000  512.3292  0.0
# 2.0     21.179196  15.0458   73.5000  0.0
# 3.0     13.295480   8.0500   69.5500  0.0

# %% [markdown]
# #### 1. Wykres słupkowy danych o cenach biletów

# %%
pclass_gruped_ticket_fare_df.plot(kind="bar");
plt.title("Wykres pokazujący szczegółowe informacje o cenach biletów");
plt.ylabel("Cena");
plt.xlabel("Klasy");

# %% [markdown]
# Możemy zauważyć, że:
# - maksymalna cena za bilet w 1 klasie, czyli najlepszej klasie była duża, **5 razy większa niż średnia cena** biletów w tej klasie, **w drugiej klasie** też była znacząco większa od śreniej, tak samo jak w 1 klasie
# - mediana wartości w pierwszej klasie pokazuje nam, **że większość cen** biletów oscylowały około średniej lub były od nie niższe
# - niektórzy pasarzerowie statku nie płacili za rejs

# %% [markdown]
# #### 2. Spożądźmy dane, które nam zobrazują jedynie bilety, które były płatne

# %%
no_free_tickts_df=df[df["fare"]>0]

# %%
pclass_gruped_no_free_ticket_fare_df=no_free_tickts_df.groupby("pclass").agg({
    "fare":["mean","median","max","min",]
})
pclass_gruped_no_free_ticket_fare_df
# Out:
#              fare
#              mean   median       max     min
# pclass
# 1.0     89.447482  61.3792  512.3292  5.0000
# 2.0     21.648108  15.0500   73.5000  9.6875
# 3.0     13.370915   8.0500   69.5500  3.1708

# %% [markdown]
# #### 3. Wykres słupkowy dany o cenach bieltów jedynie płatnych

# %%
pclass_gruped_no_free_ticket_fare_df.plot(kind="bar");
plt.title("Wykres pokazujący szczegółowe informacje o cenach biletów");
plt.ylabel("Cena");
plt.xlabel("Klasy");

# %% [markdown]
# Widzimy, że **minimalne ceny** za bilet w każdej klasie **znacząco odbiegały** od maksymalych cen za bilet, czy średnej

# %% [markdown]
# #### 4. Podsumowanie informacji o biletach platnych

# %%
pclass_gruped_ticket_fare__desc_df=no_free_tickts_df.groupby("pclass")
pclass_gruped_ticket_fare__desc_df["fare"].describe()
# Out:
#         count       mean        std     min        25%      50%       75%  \
# pclass
# 1.0     316.0  89.447482  80.259713  5.0000  31.682275  61.3792  108.9000
# 2.0     271.0  21.648108  13.382064  9.6875  13.000000  15.0500   26.0000
# 3.0     705.0  13.370915  11.476600  3.1708   7.750000   8.0500   15.2458
#
#              max
# pclass
# 1.0     512.3292
# 2.0      73.5000
# 3.0      69.5500

# %% [markdown]
# W **każdej z 3 klas** widzimy, że wartości biletów *oscylowały wokół średniej*, bo `nawet 75%` było do niej zbliżone, a tylko nieliczne były znacznie droższe

# %% [markdown]
# #### 5. Histogram cen biletów w klasach

# %%
fig, ax = plt.subplots(3, 1, figsize=(5, 7))  # zwiększ wysokość

sns.histplot(x="fare", data=classs_1_df, color="green", ax=ax[0])
sns.histplot(x="fare", data=classs_2_df, color="blue", ax=ax[1])
sns.histplot(x="fare", data=classs_3_df, color="red", ax=ax[2])

# Opcjonalnie: dodaj tytuły do każdego wykresu
ax[0].set_title("Klasa 1")
ax[0].set_xlabel("Cena za bilet")
ax[0].set_ylabel("Ilość pasażerów")
ax[0].grid(True)
ax[1].set_title("Klasa 2")
ax[2].set_xlabel("Cena za bilet")
ax[2].set_ylabel("Ilość pasażerów")
ax[1].grid(True)
ax[2].set_title("Klasa 3")
ax[2].set_xlabel("Cena za bilet")
ax[2].set_ylabel("Ilość pasażerów")
ax[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Możemy zobaczyć, że każdy z tych histogramów ma podobna budowę i pokazują, że **najwięcej w każdej klasie** zostało sprzedanych jednych z *tańszych biletów* w puli całej klasy

# %% [markdown]
# ### 4. Sprawdźmy informaje o wieku pasażerów z różnych klas

# %%
grouped_pclass_df=df.groupby("pclass")

pclass_grouped_age_df=(grouped_pclass_df.agg({
    "age":["mean", "median", "min", "max"]
}))
# pclass_grouped_age_df["age"].describe()

# %% [markdown]
# #### 1. Histogramy wieku

# %%
fig, ax = plt.subplots(3, 1, figsize=(5, 7))  # zwiększ wysokość

sns.histplot(x="age", data=classs_1_df, color="green", ax=ax[0])
sns.histplot(x="age", data=classs_2_df, color="blue", ax=ax[1])
sns.histplot(x="age", data=classs_3_df, color="red", ax=ax[2])

# Opcjonalnie: dodaj tytuły do każdego wykresu
ax[0].set_title("Klasa 1")
ax[0].grid(True)
ax[0].set_xlabel("Wiek")
ax[0].set_ylabel("Ilość pasażerów");

ax[1].set_title("Klasa 2")
ax[1].grid(True)
ax[1].set_xlabel("Wiek")
ax[1].set_ylabel("Ilość pasażerów");

ax[2].set_title("Klasa 3")
ax[2].grid(True)
ax[2].set_xlabel("Wiek")
ax[2].set_ylabel("Ilość pasażerów");

plt.tight_layout()
plt.show()

# %% [markdown]
# Na podstawie każgo z 3 histogramów możmy zauważyć, że w każdej klasię **największą** liczbę pasażerów stanowili ludzie od około` 20 do 30 roku` życia, a **najmniejszą** grupę stanwowili seniorzy od `65 do 70 roku` życia

# %% [markdown]
# #### 2. Szczególowe informacje dotyczące wieku

# %%
pclass_grouped_age_df.plot(kind="bar");
plt.title("Informacje o wieku pasażerów")
plt.ylabel("Wiek");
plt.xlabel("Klasa");

# %% [markdown]
# Możemy zauważyć, że:
# - na pokładzie znajdowały się osoby nawet `do 80 roku` życia
# - w każdej z klas średia wieku pasażrów jest zbliżona do mediany, czyli, `że 50% `pasażerów miało wiek mniejszy lub równy średniej w poszczególnej klasie

# %% [markdown]
# ### 5. Przeanalizujmy kolumnę z ocaleńcami

# %% [markdown]
# #### 1. Tworzymy wykres ile mężczyzn i kobiet przeżyło

# %%
df_sex=df.copy()

# df_sex["sex"]=df_sex["sex"].map(
#     {
#         "female":0,
#         "male":1

#     }
# )
df_sex_survived_grouped=(df_sex.groupby("sex").agg(
    sum_survived=("survived", "sum"),
)).reset_index()

# %%
df_sex_survived_grouped
# Out:
#       sex  sum_survived
# 0  female         339.0
# 1    male         161.0

# %%
plt.bar(df_sex_survived_grouped["sex"], df_sex_survived_grouped["sum_survived"], color=["blue", "orange"])
plt.title("Wykres ile mężczyzn i ile kobiet w sumie przeżyło")
plt.xlabel("Płeć")
plt.ylabel("Ilość pasażerów");

# %% [markdown]
# Z wykresu widzimy , że **przeżyło więcej** kobiet, niż mężczyzn, bo przeżyło` ok. 340 kobiet` i `około 155 mężczyzn`

# %% [markdown]
# #### 2. Analiza szans na przeżycie pasażerów w poszczególnych klasach

# %%
# pcalss_survived_grouped_df=df[df["survived"]==1]

pcalss_grouped_df = (df.groupby(['pclass']).agg(
    survived_sum= ("survived", "sum"),
    survived_count= ("survived", "count")
)).reset_index()


pcalss_grouped_df["percentage_survived"]=(pcalss_grouped_df["survived_sum"]/pcalss_grouped_df["survived_count"])*100

# %%
# 
# pcalss_grouped_df.style.background_gradient(subset="percetage_survived",cmap=cm, axis=0)

def class_color(row):
    if row['pclass'] == 1:
        return ['background-color: green' if col == 'pclass' else '' for col in row.index]
    elif row['pclass'] == 2:
        return ['background-color: red' if col == 'pclass' else '' for col in row.index]
    elif row['pclass'] == 3:
        return ['background-color: blue' if col == 'pclass' else '' for col in row.index]
    else:
        return ['' for _ in row.index]
    
def validate_count(row):
    if row['survived_count'] < 3:
        return ['background-color: red' if col == 'survived_count' else '' for col in row.index]
    if row['survived_count'] < 9:
        return ['background-color: orange' if col == 'survived_count' else '' for col in row.index]
    else:
        return ['' for _ in row.index]



def style_df(styler):

    cm=sns.light_palette(color="green", as_cmap=True)
    return(
        styler
        # .highlight_max(axis=0, props='color:white;background-color:darkgreen')
        # .highlight_min(axis=0, props='color:white;background-color:darkred')
        .apply(class_color, axis=1)
        .background_gradient(subset="percentage_survived",cmap=cm, axis=0)
        .apply(validate_count, axis=1)
        # .format(temperature_description, subset=["temperature"])
        # .format(humidity_description, subset=["humidity"])
    )

# %% [markdown]
# 1. Tabela ogólnych szans na przeżycie w klasach

# %%
pcalss_grouped_df.style.pipe(style_df)
# Out:
# <style type="text/css">
# #T_75cd3_row0_col0 {
#   background-color: green;
# }
# #T_75cd3_row0_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_75cd3_row1_col0 {
#   background-color: red;
# }
# #T_75cd3_row1_col3 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_75cd3_row2_col0 {
#   background-color: blue;
# }
# #T_75cd3_row2_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# </style>
# <table id="T_75cd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75cd3_level0_col0" class="col_heading level0 col0" >pclass</th>
#       <th id="T_75cd3_level0_col1" class="col_heading level0 col1" >survived_sum</th>
#       <th id="T_75cd3_level0_col2" class="col_heading level0 col2" >survived_count</th>
#       <th id="T_75cd3_level0_col3" class="col_heading level0 col3" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75cd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75cd3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_75cd3_row0_col1" class="data row0 col1" >200.000000</td>
#       <td id="T_75cd3_row0_col2" class="data row0 col2" >323</td>
#       <td id="T_75cd3_row0_col3" class="data row0 col3" >61.919505</td>
#     </tr>
#     <tr>
#       <th id="T_75cd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75cd3_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_75cd3_row1_col1" class="data row1 col1" >119.000000</td>
#       <td id="T_75cd3_row1_col2" class="data row1 col2" >277</td>
#       <td id="T_75cd3_row1_col3" class="data row1 col3" >42.960289</td>
#     </tr>
#     <tr>
#       <th id="T_75cd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75cd3_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_75cd3_row2_col1" class="data row2 col1" >181.000000</td>
#       <td id="T_75cd3_row2_col2" class="data row2 col2" >709</td>
#       <td id="T_75cd3_row2_col3" class="data row2 col3" >25.528914</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Widzimy, że:
# - pasażerowie w **1 klasie** mieli `62%` szans na przeżycie
# - pasażerowie w **3 klasie** mieli `25%` sznas na przeżycie

# %% [markdown]
# 2. Wykres szans nz przeżycie w poszczególnych klasach

# %%
sns.barplot(x="pclass", y="percentage_survived", data=pcalss_grouped_df, hue="pclass", palette="dark");
plt.title("Wykres szansy na przeżycie w poszczególnych klasach")
plt.xlabel("Klasy")
plt.ylabel("Sznasa na przeżycie(%)");

# %% [markdown]
# Widzimy, że najwięcej procentowo szans na przeżycie mieli pasażerowie `1 klasy` a najmniejsze `3 klasy`

# %% [markdown]
# #### 3. Wykres ocalałych w różnych klasach z rozróżnieniem na płci

# %%
pcalss_survived_sex_grouped_df = df.groupby(['pclass', "sex"]).agg(
    survived_sum= ("survived", "sum"),
    survived_count= ("survived", "count")
).reset_index()


pcalss_survived_sex_grouped_df["percentage_survived"]=(pcalss_survived_sex_grouped_df["survived_sum"]/pcalss_survived_sex_grouped_df["survived_count"])*100

# %% [markdown]
# 1. Tabela pomocnicza

# %%
pcalss_survived_sex_grouped_df.style.pipe(style_df)
# Out:
# <style type="text/css">
# #T_40e7a_row0_col0, #T_40e7a_row1_col0 {
#   background-color: green;
# }
# #T_40e7a_row0_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_40e7a_row1_col4 {
#   background-color: #b3d8b3;
#   color: #000000;
# }
# #T_40e7a_row2_col0, #T_40e7a_row3_col0 {
#   background-color: red;
# }
# #T_40e7a_row2_col4 {
#   background-color: #168b16;
#   color: #f1f1f1;
# }
# #T_40e7a_row3_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_40e7a_row4_col0, #T_40e7a_row5_col0 {
#   background-color: blue;
# }
# #T_40e7a_row4_col4 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_40e7a_row5_col4 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# </style>
# <table id="T_40e7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40e7a_level0_col0" class="col_heading level0 col0" >pclass</th>
#       <th id="T_40e7a_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_40e7a_level0_col2" class="col_heading level0 col2" >survived_sum</th>
#       <th id="T_40e7a_level0_col3" class="col_heading level0 col3" >survived_count</th>
#       <th id="T_40e7a_level0_col4" class="col_heading level0 col4" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40e7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40e7a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_40e7a_row0_col1" class="data row0 col1" >female</td>
#       <td id="T_40e7a_row0_col2" class="data row0 col2" >139.000000</td>
#       <td id="T_40e7a_row0_col3" class="data row0 col3" >144</td>
#       <td id="T_40e7a_row0_col4" class="data row0 col4" >96.527778</td>
#     </tr>
#     <tr>
#       <th id="T_40e7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40e7a_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_40e7a_row1_col1" class="data row1 col1" >male</td>
#       <td id="T_40e7a_row1_col2" class="data row1 col2" >61.000000</td>
#       <td id="T_40e7a_row1_col3" class="data row1 col3" >179</td>
#       <td id="T_40e7a_row1_col4" class="data row1 col4" >34.078212</td>
#     </tr>
#     <tr>
#       <th id="T_40e7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40e7a_row2_col0" class="data row2 col0" >2.000000</td>
#       <td id="T_40e7a_row2_col1" class="data row2 col1" >female</td>
#       <td id="T_40e7a_row2_col2" class="data row2 col2" >94.000000</td>
#       <td id="T_40e7a_row2_col3" class="data row2 col3" >106</td>
#       <td id="T_40e7a_row2_col4" class="data row2 col4" >88.679245</td>
#     </tr>
#     <tr>
#       <th id="T_40e7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40e7a_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_40e7a_row3_col1" class="data row3 col1" >male</td>
#       <td id="T_40e7a_row3_col2" class="data row3 col2" >25.000000</td>
#       <td id="T_40e7a_row3_col3" class="data row3 col3" >171</td>
#       <td id="T_40e7a_row3_col4" class="data row3 col4" >14.619883</td>
#     </tr>
#     <tr>
#       <th id="T_40e7a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40e7a_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_40e7a_row4_col1" class="data row4 col1" >female</td>
#       <td id="T_40e7a_row4_col2" class="data row4 col2" >106.000000</td>
#       <td id="T_40e7a_row4_col3" class="data row4 col3" >216</td>
#       <td id="T_40e7a_row4_col4" class="data row4 col4" >49.074074</td>
#     </tr>
#     <tr>
#       <th id="T_40e7a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40e7a_row5_col0" class="data row5 col0" >3.000000</td>
#       <td id="T_40e7a_row5_col1" class="data row5 col1" >male</td>
#       <td id="T_40e7a_row5_col2" class="data row5 col2" >75.000000</td>
#       <td id="T_40e7a_row5_col3" class="data row5 col3" >493</td>
#       <td id="T_40e7a_row5_col4" class="data row5 col4" >15.212982</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Na podstawie tabeli widzimy, że katastrofę przeżyło `ok. 97%` pasażerek **z 1 klasy**

# %% [markdown]
# 2. Wykres pokazujący szanse na przeżycie kobiet i mężczyzn

# %%
sns.barplot(x="pclass", y="percentage_survived", hue="sex", data=pcalss_survived_sex_grouped_df);
plt.title("Wykres pokazujący procentowe sznanse na przeżycie");
plt.ylabel("Sznasa na przeżycie(%)");
plt.xlabel("Klasy");

# %% [markdown]
# Możemy zauważyć, że:
# * kobiety miały dużo większe sznase na przeżycie katastrofy, szczególnie z klasy **1 i 2** gdzie przeżyło około lub ponad `90% kobiet` z tych klas
# * mężczyźni niezależnie od klasy mieli bardzo małe szanse na przeżycie, bo mniejsze niż `35%`

# %% [markdown]
# ## 5. Znajdywanie wzorców i korelacji w danych

# %% [markdown]
# ### 1. Badanie korelacji dla pasażerów co do ich wieku

# %%
def apply_age_groups_numbers(age):
    if age < 19:
        return 1
    elif age < 30:
        return 2
    elif age < 45:
        return 3
    elif age < 60:
        return 4
    elif age >= 60:
        return 5
    else:
        return 6

# %%
def apply_age_groups(age):
    if age < 19:
        return "0-18"
    elif age < 30:
        return "18-29"
    elif age < 45:
        return "30-44"
    elif age < 60:
        return "45-59"
    elif age >= 60:
        return "60+"
    else:
        return "Unknown"

# %%
age_group_df=df.copy()
age_group_df["Age_group_number"]=age_group_df["age"].apply(apply_age_groups_numbers)
age_group_df["Age_group"]=age_group_df["age"].apply(apply_age_groups)

gruped_age_df=(age_group_df.groupby(["Age_group", "Age_group_number","pclass"] ).agg(
    survived_sum=("survived", "sum"),
    survived_count=("survived", "count")
).reset_index())

gruped_age_df["percentage_survived"]=(gruped_age_df["survived_sum"]/gruped_age_df["survived_count"])*100

# %%
# 
# pcalss_grouped_df.style.background_gradient(subset="percetage_survived",cmap=cm, axis=0)

def age_group_color(row):
    color_map = {
        "0-18": "orange",
        "18-29": "lightgreen",
        "30-44": "lightblue",
        "45-59": "khaki",
        "60+": "violet",
        "Unknown": "lightgray"
    }
    age_group = row['Age_group']
    color = color_map.get(age_group, '')
    return [f'background-color: {color}; color: black' if col == 'Age_group' else '' for col in row.index]


def style_with_age_df(styler):

    cm=sns.light_palette(color="green", as_cmap=True)
    return(
        styler
        # .highlight_max(axis=0, props='color:white;background-color:darkgreen')
        # .highlight_min(axis=0, props='color:white;background-color:darkred')
        .apply(class_color, axis=1)
        .background_gradient(subset="percentage_survived",cmap=cm, axis=0)
        .apply(validate_count, axis=1)
        .apply(age_group_color, axis=1)
        # .format(temperature_description, subset=["temperature"])
        # .format(humidity_description, subset=["humidity"])
    )

# %% [markdown]
# 1. Tabela obrazująca szanse na przeżycie wszytskich pasażerów, uwzględniając wiek

# %%
gruped_age_df.style.pipe(style_with_age_df)
# Out:
# <style type="text/css">
# #T_8c623_row0_col0, #T_8c623_row1_col0, #T_8c623_row2_col0 {
#   background-color: orange;
#   color: black;
# }
# #T_8c623_row0_col2, #T_8c623_row3_col2, #T_8c623_row6_col2, #T_8c623_row9_col2, #T_8c623_row12_col2 {
#   background-color: green;
# }
# #T_8c623_row0_col5 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_8c623_row1_col2, #T_8c623_row4_col2, #T_8c623_row7_col2, #T_8c623_row10_col2, #T_8c623_row13_col2 {
#   background-color: red;
# }
# #T_8c623_row1_col5 {
#   background-color: #2b952b;
#   color: #f1f1f1;
# }
# #T_8c623_row2_col2, #T_8c623_row5_col2, #T_8c623_row8_col2, #T_8c623_row11_col2, #T_8c623_row14_col2 {
#   background-color: blue;
# }
# #T_8c623_row2_col5 {
#   background-color: #a3d0a3;
#   color: #000000;
# }
# #T_8c623_row3_col0, #T_8c623_row4_col0, #T_8c623_row5_col0 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_8c623_row3_col5 {
#   background-color: #329832;
#   color: #f1f1f1;
# }
# #T_8c623_row4_col5 {
#   background-color: #91c791;
#   color: #000000;
# }
# #T_8c623_row5_col5 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_8c623_row6_col0, #T_8c623_row7_col0, #T_8c623_row8_col0 {
#   background-color: lightblue;
#   color: black;
# }
# #T_8c623_row6_col5 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_8c623_row7_col5 {
#   background-color: #9ece9e;
#   color: #000000;
# }
# #T_8c623_row8_col5 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_8c623_row9_col0, #T_8c623_row10_col0, #T_8c623_row11_col0 {
#   background-color: khaki;
#   color: black;
# }
# #T_8c623_row9_col5 {
#   background-color: #5aac5a;
#   color: #f1f1f1;
# }
# #T_8c623_row10_col5 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_8c623_row11_col5 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_8c623_row12_col0, #T_8c623_row13_col0, #T_8c623_row14_col0 {
#   background-color: violet;
#   color: black;
# }
# #T_8c623_row12_col5 {
#   background-color: #98ca98;
#   color: #000000;
# }
# #T_8c623_row13_col4, #T_8c623_row14_col4 {
#   background-color: orange;
# }
# #T_8c623_row13_col5 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_8c623_row14_col5 {
#   background-color: #deedde;
#   color: #000000;
# }
# </style>
# <table id="T_8c623">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c623_level0_col0" class="col_heading level0 col0" >Age_group</th>
#       <th id="T_8c623_level0_col1" class="col_heading level0 col1" >Age_group_number</th>
#       <th id="T_8c623_level0_col2" class="col_heading level0 col2" >pclass</th>
#       <th id="T_8c623_level0_col3" class="col_heading level0 col3" >survived_sum</th>
#       <th id="T_8c623_level0_col4" class="col_heading level0 col4" >survived_count</th>
#       <th id="T_8c623_level0_col5" class="col_heading level0 col5" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c623_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c623_row0_col0" class="data row0 col0" >0-18</td>
#       <td id="T_8c623_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_8c623_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_8c623_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_8c623_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_8c623_row0_col5" class="data row0 col5" >85.714286</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c623_row1_col0" class="data row1 col0" >0-18</td>
#       <td id="T_8c623_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_8c623_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_8c623_row1_col3" class="data row1 col3" >31.000000</td>
#       <td id="T_8c623_row1_col4" class="data row1 col4" >43</td>
#       <td id="T_8c623_row1_col5" class="data row1 col5" >72.093023</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c623_row2_col0" class="data row2 col0" >0-18</td>
#       <td id="T_8c623_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_8c623_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_8c623_row2_col3" class="data row2 col3" >46.000000</td>
#       <td id="T_8c623_row2_col4" class="data row2 col4" >132</td>
#       <td id="T_8c623_row2_col5" class="data row2 col5" >34.848485</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c623_row3_col0" class="data row3 col0" >18-29</td>
#       <td id="T_8c623_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_8c623_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_8c623_row3_col3" class="data row3 col3" >40.000000</td>
#       <td id="T_8c623_row3_col4" class="data row3 col4" >57</td>
#       <td id="T_8c623_row3_col5" class="data row3 col5" >70.175439</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c623_row4_col0" class="data row4 col0" >18-29</td>
#       <td id="T_8c623_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_8c623_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_8c623_row4_col3" class="data row4 col3" >46.000000</td>
#       <td id="T_8c623_row4_col4" class="data row4 col4" >114</td>
#       <td id="T_8c623_row4_col5" class="data row4 col5" >40.350877</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c623_row5_col0" class="data row5 col0" >18-29</td>
#       <td id="T_8c623_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_8c623_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_8c623_row5_col3" class="data row5 col3" >106.000000</td>
#       <td id="T_8c623_row5_col4" class="data row5 col4" >426</td>
#       <td id="T_8c623_row5_col5" class="data row5 col5" >24.882629</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8c623_row6_col0" class="data row6 col0" >30-44</td>
#       <td id="T_8c623_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_8c623_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_8c623_row6_col3" class="data row6 col3" >82.000000</td>
#       <td id="T_8c623_row6_col4" class="data row6 col4" >132</td>
#       <td id="T_8c623_row6_col5" class="data row6 col5" >62.121212</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8c623_row7_col0" class="data row7 col0" >30-44</td>
#       <td id="T_8c623_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_8c623_row7_col2" class="data row7 col2" >2.000000</td>
#       <td id="T_8c623_row7_col3" class="data row7 col3" >31.000000</td>
#       <td id="T_8c623_row7_col4" class="data row7 col4" >85</td>
#       <td id="T_8c623_row7_col5" class="data row7 col5" >36.470588</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8c623_row8_col0" class="data row8 col0" >30-44</td>
#       <td id="T_8c623_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_8c623_row8_col2" class="data row8 col2" >3.000000</td>
#       <td id="T_8c623_row8_col3" class="data row8 col3" >24.000000</td>
#       <td id="T_8c623_row8_col4" class="data row8 col4" >123</td>
#       <td id="T_8c623_row8_col5" class="data row8 col5" >19.512195</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8c623_row9_col0" class="data row9 col0" >45-59</td>
#       <td id="T_8c623_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_8c623_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_8c623_row9_col3" class="data row9 col3" >50.000000</td>
#       <td id="T_8c623_row9_col4" class="data row9 col4" >87</td>
#       <td id="T_8c623_row9_col5" class="data row9 col5" >57.471264</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8c623_row10_col0" class="data row10 col0" >45-59</td>
#       <td id="T_8c623_row10_col1" class="data

# %% [markdown]
# 1. Wykres obrazujący szanse na przeżycie wszytskich pasażerów, uwzględniając wiek

# %% [markdown]
# Mając bardzo dużo danych możemy powiedzieć, że w **klasie 3** katastrofę przeżyła bardzo mała ilość mężczyzn, bo `1/5` w wieku `30-44`

# %%
sns.barplot(x="Age_group", y="percentage_survived", data=gruped_age_df, hue="pclass", palette="dark");
plt.title("Wykres pokazujący sznanse na przeżycie pasażerów")
plt.xlabel("Grupy wiekowe")
plt.ylabel("Sznasa na przeżycie(%)");

# %% [markdown]
# Na wykresie obserwujemy, że:
# * pasażerowei w wieku **0-18** klasy **1 i 2** mieli duże szanse na przeżycie które sięgały,` kolejno 84% i 72%`
#
# * Za to **najmniejsze szanse** na przeżycie katastrofy mieli pasażerowie w wieku **60+** porównując z innymi kategoriami wiekowymi w obrębie jednej klasy

# %% [markdown]
# #### 2. Sprawdźmy teraz jak wygląda korelacja gdy pasażerów rozdzielimy na płcie

# %%
# male_df=df[df["sex"]=="male"]
# # data frame samych mężczyzn
# female_df=df[df["sex"]=="female"]

male_df=drop_age_df[drop_age_df["sex"]=="male"]
# data frame samych mężczyzn
female_df=drop_age_df[drop_age_df["sex"]=="female"]
# data frame samych kobiet

# %% [markdown]
# ##### 1. Szanse na przeżycie wśród męskich pasażerów

# %%
male_df=male_df.copy()
male_df["Age_group_num"]=male_df["age"].apply(apply_age_groups_numbers)
male_df["Age_group"]=male_df["age"].apply(apply_age_groups)
male_grouped_age_survived_df=(male_df.groupby(["pclass", "Age_group"]).agg(
        survived_sum=("survived", "sum"),
        survived_count=("survived", "count")
        
    )
    .reset_index())
male_grouped_age_survived_df["percentage_survived"]=(male_grouped_age_survived_df["survived_sum"]/male_grouped_age_survived_df["survived_count"])*100;

# %% [markdown]
# 1. Tabela szans na przeżycie mężczyzn

# %%
male_grouped_age_survived_df.style.pipe(style_with_age_df)
# Out:
# <style type="text/css">
# #T_04ad9_row0_col0, #T_04ad9_row1_col0, #T_04ad9_row2_col0, #T_04ad9_row3_col0, #T_04ad9_row4_col0 {
#   background-color: green;
# }
# #T_04ad9_row0_col1, #T_04ad9_row5_col1, #T_04ad9_row10_col1 {
#   background-color: orange;
#   color: black;
# }
# #T_04ad9_row0_col3, #T_04ad9_row9_col3, #T_04ad9_row14_col3 {
#   background-color: orange;
# }
# #T_04ad9_row0_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_04ad9_row1_col1, #T_04ad9_row6_col1, #T_04ad9_row11_col1 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_04ad9_row1_col4 {
#   background-color: #6bb46b;
#   color: #f1f1f1;
# }
# #T_04ad9_row2_col1, #T_04ad9_row7_col1, #T_04ad9_row12_col1 {
#   background-color: lightblue;
#   color: black;
# }
# #T_04ad9_row2_col4 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_04ad9_row3_col1, #T_04ad9_row8_col1, #T_04ad9_row13_col1 {
#   background-color: khaki;
#   color: black;
# }
# #T_04ad9_row3_col4 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_04ad9_row4_col1, #T_04ad9_row9_col1, #T_04ad9_row14_col1 {
#   background-color: violet;
#   color: black;
# }
# #T_04ad9_row4_col4 {
#   background-color: #c6e1c6;
#   color: #000000;
# }
# #T_04ad9_row5_col0, #T_04ad9_row6_col0, #T_04ad9_row7_col0, #T_04ad9_row8_col0, #T_04ad9_row9_col0 {
#   background-color: red;
# }
# #T_04ad9_row5_col4 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_04ad9_row6_col4 {
#   background-color: #cae3ca;
#   color: #000000;
# }
# #T_04ad9_row7_col4 {
#   background-color: #cfe5cf;
#   color: #000000;
# }
# #T_04ad9_row8_col4, #T_04ad9_row14_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_04ad9_row9_col4 {
#   background-color: #beddbe;
#   color: #000000;
# }
# #T_04ad9_row10_col0, #T_04ad9_row11_col0, #T_04ad9_row12_col0, #T_04ad9_row13_col0, #T_04ad9_row14_col0 {
#   background-color: blue;
# }
# #T_04ad9_row10_col4 {
#   background-color: #aad3aa;
#   color: #000000;
# }
# #T_04ad9_row11_col4 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_04ad9_row12_col4 {
#   background-color: #bfdebf;
#   color: #000000;
# }
# #T_04ad9_row13_col4 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# </style>
# <table id="T_04ad9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04ad9_level0_col0" class="col_heading level0 col0" >pclass</th>
#       <th id="T_04ad9_level0_col1" class="col_heading level0 col1" >Age_group</th>
#       <th id="T_04ad9_level0_col2" class="col_heading level0 col2" >survived_sum</th>
#       <th id="T_04ad9_level0_col3" class="col_heading level0 col3" >survived_count</th>
#       <th id="T_04ad9_level0_col4" class="col_heading level0 col4" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04ad9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04ad9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_04ad9_row0_col1" class="data row0 col1" >0-18</td>
#       <td id="T_04ad9_row0_col2" class="data row0 col2" >6.000000</td>
#       <td id="T_04ad9_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_04ad9_row0_col4" class="data row0 col4" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04ad9_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_04ad9_row1_col1" class="data row1 col1" >18-29</td>
#       <td id="T_04ad9_row1_col2" class="data row1 col2" >11.000000</td>
#       <td id="T_04ad9_row1_col3" class="data row1 col3" >27</td>
#       <td id="T_04ad9_row1_col4" class="data row1 col4" >40.740741</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04ad9_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_04ad9_row2_col1" class="data row2 col1" >30-44</td>
#       <td id="T_04ad9_row2_col2" class="data row2 col2" >18.000000</td>
#       <td id="T_04ad9_row2_col3" class="data row2 col3" >47</td>
#       <td id="T_04ad9_row2_col4" class="data row2 col4" >38.297872</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04ad9_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_04ad9_row3_col1" class="data row3 col1" >45-59</td>
#       <td id="T_04ad9_row3_col2" class="data row3 col2" >16.000000</td>
#       <td id="T_04ad9_row3_col3" class="data row3 col3" >52</td>
#       <td id="T_04ad9_row3_col4" class="data row3 col4" >30.769231</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04ad9_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_04ad9_row4_col1" class="data row4 col1" >60+</td>
#       <td id="T_04ad9_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_04ad9_row4_col3" class="data row4 col3" >17</td>
#       <td id="T_04ad9_row4_col4" class="data row4 col4" >11.764706</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04ad9_row5_col0" class="data row5 col0" >2.000000</td>
#       <td id="T_04ad9_row5_col1" class="data row5 col1" >0-18</td>
#       <td id="T_04ad9_row5_col2" class="data row5 col2" >11.000000</td>
#       <td id="T_04ad9_row5_col3" class="data row5 col3" >22</td>
#       <td id="T_04ad9_row5_col4" class="data row5 col4" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_04ad9_row6_col0" class="data row6 col0" >2.000000</td>
#       <td id="T_04ad9_row6_col1" class="data row6 col1" >18-29</td>
#       <td id="T_04ad9_row6_col2" class="data row6 col2" >6.000000</td>
#       <td id="T_04ad9_row6_col3" class="data row6 col3" >57</td>
#       <td id="T_04ad9_row6_col4" class="data row6 col4" >10.526316</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_04ad9_row7_col0" class="data row7 col0" >2.000000</td>
#       <td id="T_04ad9_row7_col1" class="data row7 col1" >30-44</td>
#       <td id="T_04ad9_row7_col2" class="data row7 col2" >5.000000</td>
#       <td id="T_04ad9_row7_col3" class="data row7 col3" >56</td>
#       <td id="T_04ad9_row7_col4" class="data row7 col4" >8.928571</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_04ad9_row8_col0" class="data row8 col0" >2.000000</td>
#       <td id="T_04ad9_row8_col1" class="data row8 col1" >45-59</td>
#       <td id="T_04ad9_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_04ad9_row8_col3" class="data row8 col3" >16</td>
#       <td id="T_04ad9_row8_col4" class="data row8 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_04ad9_row9_col0" class="data row9 col0" >2.000000</td>
#       <td id="T_04ad9_row9_col1" class="data row9 col1" >60+</td>
#       <td id="T_04ad9_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_04ad9_row9_col3" class="data row9 col3" >7</td>
#       <td id="T_04ad9_row9_col4" class="data row9 col4" >14.285714</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_04ad9_row10_col0" class="data row10 col0" >3.000000</td>
#       <td id="T_04ad9_row10_col1" class="data row10 col1" >0-18</td>
#       <td id="T_04ad9_row10_col2" class="data row10 col2" >15.000000</td>
#       <td id="T_04ad9_row10_col3" class="data row10 col3" >73</td>
#       <td id="T_04ad9_row10_col4" class="data row10 col4" >20.547945</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_04ad9_row11_col0" class="data row11 col0" >3.000000</td>
#       <td id="T_04ad9_row11_col1" class="data row11 col1" >18-29</td>
#       <td id="T_04ad9_row11_col2" class="data row11 col2" >30.000000</td>
#       <td id="T_04ad9_row11_col3" class="data row11 col3" >164</td>
#       <td id="T_04ad9_row11_col4" class="data row11 col4" >18.292683</td>
#     </tr>
#     <tr>
#       <th id="T_04ad9_level0_row12" class="row_heading level0 ro

# %% [markdown]
# Na podstawie tabeli, musimy się zastanowić, `czy 8, 7 i 5` pasażerów to wsytarczająca ilość, aby wysnuwać wiążace wnioski

# %% [markdown]
# 1. Wykres pokazujący sznase u mężczyzn

# %%
sns.barplot(x="Age_group", y="percentage_survived", data=male_grouped_age_survived_df, hue="pclass", palette="dark");
plt.title("Wykres pokazujący sznanse na przeżycie mężczyzn")
plt.xlabel("Grupy wiekowe")
plt.ylabel("Sznasa na przeżycie(%)");

# %% [markdown]
# Widzimy, że:
# * mężczyźni w wieku **od 0-18 lat** mieli około `75%` szans na przeżycie katastrofy
# * mężczyźni z klasy 2 **od 0-18 lat** przeżyli w małym stopniu bo `ok. 50%`z nich przeżyło
# * męscy pasażerowie z **klasy 2 i 3**, którzy byli **starsi niż 18 lat** meili sznase na przeżycie `21% i mniej`

# %% [markdown]
# ##### 2. Analiza dla kobiecej częście pasażerów

# %%
female_df=female_df.copy()
female_df["Age_group_num"]=female_df["age"].apply(apply_age_groups_numbers)
female_df["Age_group"]=female_df["age"].apply(apply_age_groups)
female_grouped_age_survived_df=(female_df.groupby(["pclass", "Age_group"]).agg(
        survived_sum=("survived", "sum"),
        survived_count=("survived", "count")
    )
    .reset_index())
female_grouped_age_survived_df["percentage_survived"]=(female_grouped_age_survived_df["survived_sum"]/female_grouped_age_survived_df["survived_count"])*100;

# %% [markdown]
# 1. Tabela szans na przeżycie kobiet

# %%
female_grouped_age_survived_df.style.pipe(style_with_age_df)
# Out:
# <style type="text/css">
# #T_f06e9_row0_col0, #T_f06e9_row1_col0, #T_f06e9_row2_col0, #T_f06e9_row3_col0, #T_f06e9_row4_col0 {
#   background-color: green;
# }
# #T_f06e9_row0_col1, #T_f06e9_row5_col1, #T_f06e9_row10_col1 {
#   background-color: orange;
#   color: black;
# }
# #T_f06e9_row0_col4 {
#   background-color: #118911;
#   color: #f1f1f1;
# }
# #T_f06e9_row1_col1, #T_f06e9_row6_col1, #T_f06e9_row11_col1 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_f06e9_row1_col4 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_f06e9_row2_col1, #T_f06e9_row7_col1, #T_f06e9_row12_col1 {
#   background-color: lightblue;
#   color: black;
# }
# #T_f06e9_row2_col4 {
#   background-color: #058205;
#   color: #f1f1f1;
# }
# #T_f06e9_row3_col1, #T_f06e9_row8_col1, #T_f06e9_row13_col1 {
#   background-color: khaki;
#   color: black;
# }
# #T_f06e9_row3_col4 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_f06e9_row4_col1, #T_f06e9_row9_col1, #T_f06e9_row14_col1 {
#   background-color: violet;
#   color: black;
# }
# #T_f06e9_row4_col4 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_f06e9_row5_col0, #T_f06e9_row6_col0, #T_f06e9_row7_col0, #T_f06e9_row8_col0, #T_f06e9_row9_col0, #T_f06e9_row9_col3, #T_f06e9_row14_col3 {
#   background-color: red;
# }
# #T_f06e9_row5_col4 {
#   background-color: #0b850b;
#   color: #f1f1f1;
# }
# #T_f06e9_row6_col4 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_f06e9_row7_col4 {
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_f06e9_row8_col4 {
#   background-color: #158a15;
#   color: #f1f1f1;
# }
# #T_f06e9_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_f06e9_row10_col0, #T_f06e9_row11_col0, #T_f06e9_row12_col0, #T_f06e9_row13_col0, #T_f06e9_row14_col0 {
#   background-color: blue;
# }
# #T_f06e9_row10_col4 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_f06e9_row11_col4 {
#   background-color: #79bc79;
#   color: #000000;
# }
# #T_f06e9_row12_col4 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_f06e9_row13_col3 {
#   background-color: orange;
# }
# #T_f06e9_row13_col4 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_f06e9_row14_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f06e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f06e9_level0_col0" class="col_heading level0 col0" >pclass</th>
#       <th id="T_f06e9_level0_col1" class="col_heading level0 col1" >Age_group</th>
#       <th id="T_f06e9_level0_col2" class="col_heading level0 col2" >survived_sum</th>
#       <th id="T_f06e9_level0_col3" class="col_heading level0 col3" >survived_count</th>
#       <th id="T_f06e9_level0_col4" class="col_heading level0 col4" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f06e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f06e9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f06e9_row0_col1" class="data row0 col1" >0-18</td>
#       <td id="T_f06e9_row0_col2" class="data row0 col2" >12.000000</td>
#       <td id="T_f06e9_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_f06e9_row0_col4" class="data row0 col4" >92.307692</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f06e9_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_f06e9_row1_col1" class="data row1 col1" >18-29</td>
#       <td id="T_f06e9_row1_col2" class="data row1 col2" >29.000000</td>
#       <td id="T_f06e9_row1_col3" class="data row1 col3" >30</td>
#       <td id="T_f06e9_row1_col4" class="data row1 col4" >96.666667</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f06e9_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_f06e9_row2_col1" class="data row2 col1" >30-44</td>
#       <td id="T_f06e9_row2_col2" class="data row2 col2" >45.000000</td>
#       <td id="T_f06e9_row2_col3" class="data row2 col3" >46</td>
#       <td id="T_f06e9_row2_col4" class="data row2 col4" >97.826087</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f06e9_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_f06e9_row3_col1" class="data row3 col1" >45-59</td>
#       <td id="T_f06e9_row3_col2" class="data row3 col2" >34.000000</td>
#       <td id="T_f06e9_row3_col3" class="data row3 col3" >35</td>
#       <td id="T_f06e9_row3_col4" class="data row3 col4" >97.142857</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f06e9_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_f06e9_row4_col1" class="data row4 col1" >60+</td>
#       <td id="T_f06e9_row4_col2" class="data row4 col2" >8.000000</td>
#       <td id="T_f06e9_row4_col3" class="data row4 col3" >9</td>
#       <td id="T_f06e9_row4_col4" class="data row4 col4" >88.888889</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f06e9_row5_col0" class="data row5 col0" >2.000000</td>
#       <td id="T_f06e9_row5_col1" class="data row5 col1" >0-18</td>
#       <td id="T_f06e9_row5_col2" class="data row5 col2" >20.000000</td>
#       <td id="T_f06e9_row5_col3" class="data row5 col3" >21</td>
#       <td id="T_f06e9_row5_col4" class="data row5 col4" >95.238095</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f06e9_row6_col0" class="data row6 col0" >2.000000</td>
#       <td id="T_f06e9_row6_col1" class="data row6 col1" >18-29</td>
#       <td id="T_f06e9_row6_col2" class="data row6 col2" >36.000000</td>
#       <td id="T_f06e9_row6_col3" class="data row6 col3" >41</td>
#       <td id="T_f06e9_row6_col4" class="data row6 col4" >87.804878</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f06e9_row7_col0" class="data row7 col0" >2.000000</td>
#       <td id="T_f06e9_row7_col1" class="data row7 col1" >30-44</td>
#       <td id="T_f06e9_row7_col2" class="data row7 col2" >26.000000</td>
#       <td id="T_f06e9_row7_col3" class="data row7 col3" >29</td>
#       <td id="T_f06e9_row7_col4" class="data row7 col4" >89.655172</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f06e9_row8_col0" class="data row8 col0" >2.000000</td>
#       <td id="T_f06e9_row8_col1" class="data row8 col1" >45-59</td>
#       <td id="T_f06e9_row8_col2" class="data row8 col2" >10.000000</td>
#       <td id="T_f06e9_row8_col3" class="data row8 col3" >11</td>
#       <td id="T_f06e9_row8_col4" class="data row8 col4" >90.909091</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f06e9_row9_col0" class="data row9 col0" >2.000000</td>
#       <td id="T_f06e9_row9_col1" class="data row9 col1" >60+</td>
#       <td id="T_f06e9_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_f06e9_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_f06e9_row9_col4" class="data row9 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f06e9_row10_col0" class="data row10 col0" >3.000000</td>
#       <td id="T_f06e9_row10_col1" class="data row10 col1" >0-18</td>
#       <td id="T_f06e9_row10_col2" class="data row10 col2" >31.000000</td>
#       <td id="T_f06e9_row10_col3" class="data row10 col3" >59</td>
#       <td id="T_f06e9_row10_col4" class="data row10 col4" >52.542373</td>
#     </tr>
#     <tr>
#       <th id="T_f06e9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f06e9_row11_col0" class="data row11 col0" >3.000000</td>
#       <td id="T_f06e9_row11_col1" class="data row11 col1" >18-29</td>
#       <td id="T_f06e9_row11_col2" class="data row11 col2" >26.000000</td>
#       <td id="T_f06e9_row11_col3" class="data row11 col3" >54</td>
#       <td id="T_f06e9_row11_col4" class="data row11 col4" >48.148148</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# Mając jedynie jednego pasażera do obserwacji **nie powinniśmy zwracać dużą** uwagę na to, że w kalsie 3 przeżyło `100%` pasażerek w wieku **60+**

# %% [markdown]
# 2. Wykres szans kobiet na przeżycie

# %%
sns.barplot(x="Age_group", y="percentage_survived", data=female_grouped_age_survived_df, hue="pclass");
plt.title("Wykres pokazujący sznanse na przeżycie kobiet")
plt.xlabel("Grupy wiekowe")
plt.ylabel("Sznasa na przeżycie(%)");

# %% [markdown]
# Patrząc na wykres możemy stwierdzić, że:
# * kobiety w **1 i 2** klasie niezależnie od wieku miały bardzo dużą szansę na przeżycie `ponad 85%`, nie biorąc pod uwagę wieku **60+** w kalsie 2, gdyż była 1 taka osoba, która nie przeżyła
# * natomist w klasie 3 kobiety miały `mniej niż 55%` szans na przeżycie

# %% [markdown]
# ### 3. Sprawdźmy korelacje między cenami biletu, a przeżywalnością wśród pasażerów

# %% [markdown]
# #### 1. Sprawdzamy zaleznosć cen biletów do szans na przeżycie

# %% [markdown]
# Tworzymy funkcję do utworzenia kategorii opierając się o ceny biletów

# %%
def apply_fare_groups(cost):
    if cost <20:
        return "0-19"
    elif cost < 40:
        return "20-39"
    elif cost < 80:
        return "40-79"
    elif cost < 100:
        return "80-99"
    elif cost <311:
        return "100-310"
    else:
        return ">310"

# %%
def apply_age_groups_numbers(cost):
    if cost < 19:
        return 1
    elif cost < 30:
        return 2
    elif cost < 45:
        return 3
    elif cost < 60:
        return 4
    elif cost >= 60:
        return 5
    else:
        return 6

# %%
def fare_color(row):
    color_map = {
        "0-19": "orange",
        "20-39": "lightgreen",
        "40-79": "lightblue",
        "80-99": "khaki",
        "100-310": "violet",
        ">310": "lightgray"
    }
    age_group = row['fare_groups']
    color = color_map.get(age_group, '')
    return [f'background-color: {color}; color: black' if col == 'fare_groups' else '' for col in row.index]

def style_with_fare_df(styler):

    cm=sns.light_palette(color="green", as_cmap=True)
    return(
        styler
        # .highlight_max(axis=0, props='color:white;background-color:darkgreen')
        # .highlight_min(axis=0, props='color:white;background-color:darkred')
        .apply(class_color, axis=1)
        .background_gradient(subset="percentage_survived",cmap=cm, axis=0)
        .apply(validate_count, axis=1)
        .apply(fare_color, axis=1)
        # .format(temperature_description, subset=["temperature"])
        # .format(humidity_description, subset=["humidity"])
    )

# %%
df_fare=df.copy()
df_fare["fare_groups"]=df_fare["fare"].apply(apply_fare_groups)
fare_grouped_survived_df=(df_fare.groupby(["fare_groups", "pclass"]).agg(
    survived_sum=("survived", "sum"),
    survived_count=("survived", "count")
).reset_index())

fare_grouped_survived_df["percentage_survived"]=(fare_grouped_survived_df["survived_sum"]/fare_grouped_survived_df["survived_count"])*100

# %% [markdown]
# 1. Tabela szans na przeżycie patrząc na ceny biletów

# %%
fare_grouped_survived_df.style.pipe(style_with_fare_df)
# Out:
# <style type="text/css">
# #T_7a040_row0_col0, #T_7a040_row1_col0, #T_7a040_row2_col0 {
#   background-color: orange;
#   color: black;
# }
# #T_7a040_row0_col1, #T_7a040_row3_col1, #T_7a040_row4_col1, #T_7a040_row7_col1, #T_7a040_row10_col1, #T_7a040_row11_col1 {
#   background-color: green;
# }
# #T_7a040_row0_col3, #T_7a040_row11_col3 {
#   background-color: orange;
# }
# #T_7a040_row0_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_7a040_row1_col1, #T_7a040_row5_col1, #T_7a040_row8_col1 {
#   background-color: red;
# }
# #T_7a040_row1_col4 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_7a040_row2_col1, #T_7a040_row6_col1, #T_7a040_row9_col1 {
#   background-color: blue;
# }
# #T_7a040_row2_col4 {
#   background-color: #c6e1c6;
#   color: #000000;
# }
# #T_7a040_row3_col0 {
#   background-color: violet;
#   color: black;
# }
# #T_7a040_row3_col4 {
#   background-color: #50a750;
#   color: #f1f1f1;
# }
# #T_7a040_row4_col0, #T_7a040_row5_col0, #T_7a040_row6_col0 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_7a040_row4_col4 {
#   background-color: #84c084;
#   color: #000000;
# }
# #T_7a040_row5_col4 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_7a040_row6_col4 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_7a040_row7_col0, #T_7a040_row8_col0, #T_7a040_row9_col0 {
#   background-color: lightblue;
#   color: black;
# }
# #T_7a040_row7_col4 {
#   background-color: #67b267;
#   color: #f1f1f1;
# }
# #T_7a040_row8_col4 {
#   background-color: #a7d2a7;
#   color: #000000;
# }
# #T_7a040_row9_col4 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_7a040_row10_col0 {
#   background-color: khaki;
#   color: black;
# }
# #T_7a040_row10_col4 {
#   background-color: #319831;
#   color: #f1f1f1;
# }
# #T_7a040_row11_col0 {
#   background-color: lightgray;
#   color: black;
# }
# #T_7a040_row11_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a040">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a040_level0_col0" class="col_heading level0 col0" >fare_groups</th>
#       <th id="T_7a040_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_7a040_level0_col2" class="col_heading level0 col2" >survived_sum</th>
#       <th id="T_7a040_level0_col3" class="col_heading level0 col3" >survived_count</th>
#       <th id="T_7a040_level0_col4" class="col_heading level0 col4" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a040_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a040_row0_col0" class="data row0 col0" >0-19</td>
#       <td id="T_7a040_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_7a040_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_7a040_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_7a040_row0_col4" class="data row0 col4" >12.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a040_row1_col0" class="data row1 col0" >0-19</td>
#       <td id="T_7a040_row1_col1" class="data row1 col1" >2.000000</td>
#       <td id="T_7a040_row1_col2" class="data row1 col2" >52.000000</td>
#       <td id="T_7a040_row1_col3" class="data row1 col3" >152</td>
#       <td id="T_7a040_row1_col4" class="data row1 col4" >34.210526</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a040_row2_col0" class="data row2 col0" >0-19</td>
#       <td id="T_7a040_row2_col1" class="data row2 col1" >3.000000</td>
#       <td id="T_7a040_row2_col2" class="data row2 col2" >156.000000</td>
#       <td id="T_7a040_row2_col3" class="data row2 col3" >593</td>
#       <td id="T_7a040_row2_col4" class="data row2 col4" >26.306914</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a040_row3_col0" class="data row3 col0" >100-310</td>
#       <td id="T_7a040_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_7a040_row3_col2" class="data row3 col2" >56.000000</td>
#       <td id="T_7a040_row3_col3" class="data row3 col3" >80</td>
#       <td id="T_7a040_row3_col4" class="data row3 col4" >70.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a040_row4_col0" class="data row4 col0" >20-39</td>
#       <td id="T_7a040_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_7a040_row4_col2" class="data row4 col2" >48.000000</td>
#       <td id="T_7a040_row4_col3" class="data row4 col3" >94</td>
#       <td id="T_7a040_row4_col4" class="data row4 col4" >51.063830</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a040_row5_col0" class="data row5 col0" >20-39</td>
#       <td id="T_7a040_row5_col1" class="data row5 col1" >2.000000</td>
#       <td id="T_7a040_row5_col2" class="data row5 col2" >61.000000</td>
#       <td id="T_7a040_row5_col3" class="data row5 col3" >109</td>
#       <td id="T_7a040_row5_col4" class="data row5 col4" >55.963303</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a040_row6_col0" class="data row6 col0" >20-39</td>
#       <td id="T_7a040_row6_col1" class="data row6 col1" >3.000000</td>
#       <td id="T_7a040_row6_col2" class="data row6 col2" >19.000000</td>
#       <td id="T_7a040_row6_col3" class="data row6 col3" >89</td>
#       <td id="T_7a040_row6_col4" class="data row6 col4" >21.348315</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a040_row7_col0" class="data row7 col0" >40-79</td>
#       <td id="T_7a040_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_7a040_row7_col2" class="data row7 col2" >64.000000</td>
#       <td id="T_7a040_row7_col3" class="data row7 col3" >104</td>
#       <td id="T_7a040_row7_col4" class="data row7 col4" >61.538462</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a040_row8_col0" class="data row8 col0" >40-79</td>
#       <td id="T_7a040_row8_col1" class="data row8 col1" >2.000000</td>
#       <td id="T_7a040_row8_col2" class="data row8 col2" >6.000000</td>
#       <td id="T_7a040_row8_col3" class="data row8 col3" >16</td>
#       <td id="T_7a040_row8_col4" class="data row8 col4" >37.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a040_row9_col0" class="data row9 col0" >40-79</td>
#       <td id="T_7a040_row9_col1" class="data row9 col1" >3.000000</td>
#       <td id="T_7a040_row9_col2" class="data row9 col2" >6.000000</td>
#       <td id="T_7a040_row9_col3" class="data row9 col3" >27</td>
#       <td id="T_7a040_row9_col4" class="data row9 col4" >22.222222</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a040_row10_col0" class="data row10 col0" >80-99</td>
#       <td id="T_7a040_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_7a040_row10_col2" class="data row10 col2" >27.000000</td>
#       <td id="T_7a040_row10_col3" class="data row10 col3" >33</td>
#       <td id="T_7a040_row10_col4" class="data row10 col4" >81.818182</td>
#     </tr>
#     <tr>
#       <th id="T_7a040_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a040_row11_col0" class="data row11 col0" >>310</td>
#       <td id="T_7a040_row11_col1" class="data row11 col1" >1.000000</td>
#       <td id="T_7a040_row11_col2" class="data row11 col2" >4.000000</td>
#       <td id="T_7a040_row11_col3" class="data row11 col3" >4</td>
#       <td id="T_7a040_row11_col4" class="data row11 col4" >100.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Mamy małą próbkę porównawczą, aby zadeklarować, że jeśli pasażer zapłacił za bilet **więcej niż 310** miał ogromne szanse na przeżycie

# %% [markdown]
# 2. Wykres szans do cen biletów

# %%
custom_order = ["0-19", "20-39", "40-79", "80-99", "100-310", ">310"]

# Wymuś kolejność kategorii
fare_grouped_survived_df["fare_groups"] = pd.Categorical(fare_grouped_survived_df["fare_groups"], categories=custom_order, ordered=True)
sns.barplot(x="fare_groups", y="percentage_survived", data=fare_grouped_survived_df, palette="dark", hue="pclass")
plt.title("Wykres szansy na przeżycie do cen za bilety");
plt.xlabel("Kategorie cenowe biletów")
plt.ylabel("Szansa na przeżycie (%)");

# %% [markdown]
# Z wykresów możemy wyciągnąc wnosiek, że:
# * wśród pasażerów z 1 klasy, którzy kupili bilet za **80-99** przeżyło `81%`
# * pasażerowie, z klasy pierwszej, kórzy kupili tańsze bilety w cenie 0-40 mieli mnijesze szanse na przeżycie bo `mniej niż 50%` niżinni w tej klasie

# %% [markdown]
# ### 4. Przeanalizujmy, czy wielkość rodziny pasażera. Czy ilość rodzeństwa lub małżonek/małżonka wpływała na szanse na przetrwanie

# %% [markdown]
# #### 1. Tabela szans na przeżycie uwzględniając ilość małzonek/a/rodzeństwa

# %%
# 
# pcalss_grouped_df.style.background_gradient(subset="percetage_survived",cmap=cm, axis=0)

def sibsp_color(row):
    color_map = {
        0: "lightgray",
        1: "lightgreen",
        2: "lightskyblue",
        3: "lightcoral",
        4: "gold",
        5: "plum",
        6: "darkseagreen",
        7: "salmon",
        8: "mediumslateblue"
    }
    value = row['sibsp']
    color = color_map.get(value, '')
    return [f'background-color: {color}; color: black' if col == 'sibsp' else '' for col in row.index]



def style_with_sibsp_df(styler):

    cm=sns.light_palette(color="green", as_cmap=True)
    return(
        styler
        # .highlight_max(axis=0, props='color:white;background-color:darkgreen')
        # .highlight_min(axis=0, props='color:white;background-color:darkred')
        .apply(class_color, axis=1)
        .background_gradient(subset="percentage_survived",cmap=cm, axis=0)
        .apply(validate_count, axis=1)
        .apply(sibsp_color, axis=1)
        # .format(temperature_description, subset=["temperature"])
        # .format(humidity_description, subset=["humidity"])
    )

# %%
sibps_grouped_survived_df=(df.groupby(["sibsp","pclass"]).agg(
   survived_sum= ("survived", "sum"),
    survived_count= ("survived", "count")
).reset_index())
sibps_grouped_survived_df["percentage_survived"]=(sibps_grouped_survived_df["survived_sum"]/sibps_grouped_survived_df["survived_count"])*100

# %% [markdown]
# #### 2. Wykres szans na przeżycie uwzględniając ilość małzonek/a/rodzeństwa

# %%
sibps_grouped_survived_df.style.pipe(style_with_sibsp_df)
# Out:
# <style type="text/css">
# #T_b998e_row0_col0, #T_b998e_row1_col0, #T_b998e_row2_col0 {
#   background-color: lightgray;
#   color: black;
# }
# #T_b998e_row0_col1, #T_b998e_row3_col1, #T_b998e_row6_col1, #T_b998e_row9_col1 {
#   background-color: green;
# }
# #T_b998e_row0_col4 {
#   background-color: #67b267;
#   color: #f1f1f1;
# }
# #T_b998e_row1_col1, #T_b998e_row4_col1, #T_b998e_row7_col1, #T_b998e_row10_col1, #T_b998e_row10_col3 {
#   background-color: red;
# }
# #T_b998e_row1_col4 {
#   background-color: #91c791;
#   color: #000000;
# }
# #T_b998e_row2_col1, #T_b998e_row5_col1, #T_b998e_row8_col1, #T_b998e_row11_col1, #T_b998e_row12_col1, #T_b998e_row13_col1, #T_b998e_row14_col1 {
#   background-color: blue;
# }
# #T_b998e_row2_col4 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_b998e_row3_col0, #T_b998e_row4_col0, #T_b998e_row5_col0 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_b998e_row3_col4 {
#   background-color: #47a347;
#   color: #f1f1f1;
# }
# #T_b998e_row4_col4 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_b998e_row5_col4 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_b998e_row6_col0, #T_b998e_row7_col0, #T_b998e_row8_col0 {
#   background-color: lightskyblue;
#   color: black;
# }
# #T_b998e_row6_col3, #T_b998e_row9_col3, #T_b998e_row13_col3 {
#   background-color: orange;
# }
# #T_b998e_row6_col4 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_b998e_row7_col4 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_b998e_row8_col4 {
#   background-color: #abd4ab;
#   color: #000000;
# }
# #T_b998e_row9_col0, #T_b998e_row10_col0, #T_b998e_row11_col0 {
#   background-color: lightcoral;
#   color: black;
# }
# #T_b998e_row9_col4 {
#   background-color: #3a9c3a;
#   color: #f1f1f1;
# }
# #T_b998e_row10_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_b998e_row11_col4, #T_b998e_row12_col4 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_b998e_row12_col0 {
#   background-color: gold;
#   color: black;
# }
# #T_b998e_row13_col0 {
#   background-color: plum;
#   color: black;
# }
# #T_b998e_row13_col4, #T_b998e_row14_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_b998e_row14_col0 {
#   background-color: mediumslateblue;
#   color: black;
# }
# </style>
# <table id="T_b998e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b998e_level0_col0" class="col_heading level0 col0" >sibsp</th>
#       <th id="T_b998e_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_b998e_level0_col2" class="col_heading level0 col2" >survived_sum</th>
#       <th id="T_b998e_level0_col3" class="col_heading level0 col3" >survived_count</th>
#       <th id="T_b998e_level0_col4" class="col_heading level0 col4" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b998e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b998e_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_b998e_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_b998e_row0_col2" class="data row0 col2" >111.000000</td>
#       <td id="T_b998e_row0_col3" class="data row0 col3" >198</td>
#       <td id="T_b998e_row0_col4" class="data row0 col4" >56.060606</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b998e_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_b998e_row1_col1" class="data row1 col1" >2.000000</td>
#       <td id="T_b998e_row1_col2" class="data row1 col2" >69.000000</td>
#       <td id="T_b998e_row1_col3" class="data row1 col3" >182</td>
#       <td id="T_b998e_row1_col4" class="data row1 col4" >37.912088</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b998e_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_b998e_row2_col1" class="data row2 col1" >3.000000</td>
#       <td id="T_b998e_row2_col2" class="data row2 col2" >129.000000</td>
#       <td id="T_b998e_row2_col3" class="data row2 col3" >511</td>
#       <td id="T_b998e_row2_col4" class="data row2 col4" >25.244618</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b998e_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_b998e_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_b998e_row3_col2" class="data row3 col2" >79.000000</td>
#       <td id="T_b998e_row3_col3" class="data row3 col3" >113</td>
#       <td id="T_b998e_row3_col4" class="data row3 col4" >69.911504</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b998e_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_b998e_row4_col1" class="data row4 col1" >2.000000</td>
#       <td id="T_b998e_row4_col2" class="data row4 col2" >43.000000</td>
#       <td id="T_b998e_row4_col3" class="data row4 col3" >82</td>
#       <td id="T_b998e_row4_col4" class="data row4 col4" >52.439024</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b998e_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_b998e_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_b998e_row5_col2" class="data row5 col2" >41.000000</td>
#       <td id="T_b998e_row5_col3" class="data row5 col3" >124</td>
#       <td id="T_b998e_row5_col4" class="data row5 col4" >33.064516</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b998e_row6_col0" class="data row6 col0" >2.000000</td>
#       <td id="T_b998e_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_b998e_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_b998e_row6_col3" class="data row6 col3" >8</td>
#       <td id="T_b998e_row6_col4" class="data row6 col4" >87.500000</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b998e_row7_col0" class="data row7 col0" >2.000000</td>
#       <td id="T_b998e_row7_col1" class="data row7 col1" >2.000000</td>
#       <td id="T_b998e_row7_col2" class="data row7 col2" >6.000000</td>
#       <td id="T_b998e_row7_col3" class="data row7 col3" >12</td>
#       <td id="T_b998e_row7_col4" class="data row7 col4" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b998e_row8_col0" class="data row8 col0" >2.000000</td>
#       <td id="T_b998e_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_b998e_row8_col2" class="data row8 col2" >6.000000</td>
#       <td id="T_b998e_row8_col3" class="data row8 col3" >22</td>
#       <td id="T_b998e_row8_col4" class="data row8 col4" >27.272727</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b998e_row9_col0" class="data row9 col0" >3.000000</td>
#       <td id="T_b998e_row9_col1" class="data row9 col1" >1.000000</td>
#       <td id="T_b998e_row9_col2" class="data row9 col2" >3.000000</td>
#       <td id="T_b998e_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_b998e_row9_col4" class="data row9 col4" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b998e_row10_col0" class="data row10 col0" >3.000000</td>
#       <td id="T_b998e_row10_col1" class="data row10 col1" >2.000000</td>
#       <td id="T_b998e_row10_col2" class="data row10 col2" >1.000000</td>
#       <td id="T_b998e_row10_col3" class="data row10 col3" >1</td>
#       <td id="T_b998e_row10_col4" class="data row10 col4" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b998e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b998e_row11_col0" class="data row11 col0" >3.000000</td>
#       <td id="T_b998e_row11_col1" class="data row11 col1" >3.000000</td>
#       <td id="T_b998e_row11_col2" class="data row11 col2" >2.000000</td>
#       <td id="T_b998e_row11_col3" class="data row11 col3" >15</td>
#       <td id="T_b998e_row11_c

# %% [markdown]
# Patrząc na tabelę nie możemy bardzo skupiać na tym, że szanse  na przeżycie w pasażera, który **miał 3 małzonek/a/rodzeństwa** na pokładzie, w klasie 2 wynosiły `100%`, gdyż mieliśmy 1 takiego pasażera do obserwacji

# %%
sns.barplot(x="sibsp", y="percentage_survived", hue="pclass", data=sibps_grouped_survived_df, palette="muted6");
plt.title("Wykres pokazujący procentowe sznanse na przeżycie");
plt.xlabel("Ilość rodziców/małżonki/a, jaką pasażer miał na pokłądzie")
plt.ylabel("Szansa na przeżycie (%)");

# %% [markdown]
# Możemy tu zauważyć, że wśród pasażerów z klasy pierwszej, którzy mieli 2 rodziców/żony/męża na pokładzie przeżyło `88%` z nich

# %% [markdown]
# ### 5. Wpływ ilości rodziców/dzieci na szansę na przeżycie pasażera

# %% [markdown]
# #### 1. Tabela szans na przeżycie uwzględniając ilość rodziców/dzieci

# %%
# 
# pcalss_grouped_df.style.background_gradient(subset="percetage_survived",cmap=cm, axis=0)

def parch_color(row):
    color_map = {
        0: "lightgray",
        1: "lightgreen",
        2: "lightskyblue",
        3: "lightcoral",
        4: "gold",
        5: "plum",
        6: "darkseagreen",
        7: "salmon",
        8: "mediumslateblue",
        9: "saphire"
    }
    value = row['parch']
    color = color_map.get(value, '')
    return [f'background-color: {color}; color: black' if col == 'parch' else '' for col in row.index]



def style_parch_df(styler):

    cm=sns.light_palette(color="green", as_cmap=True)
    return(
        styler
        # .highlight_max(axis=0, props='color:white;background-color:darkgreen')
        # .highlight_min(axis=0, props='color:white;background-color:darkred')
        .apply(class_color, axis=1)
        .background_gradient(subset="percentage_survived",cmap=cm, axis=0)
        .apply(validate_count, axis=1)
        .apply(parch_color, axis=1)
        # .format(temperature_description, subset=["temperature"])
        # .format(humidity_description, subset=["humidity"])
    )

# %%
parch_grouped_survived_df=(df.groupby(["parch","pclass"]).agg(
   survived_sum= ("survived", "sum"),
    survived_count= ("survived", "count")
).reset_index())
parch_grouped_survived_df["percentage_survived"]=(parch_grouped_survived_df["survived_sum"]/parch_grouped_survived_df["survived_count"])*100

parch_grouped_survived_df.style.pipe(style_parch_df)
# Out:
# <style type="text/css">
# #T_c7bd9_row0_col0, #T_c7bd9_row1_col0, #T_c7bd9_row2_col0 {
#   background-color: lightgray;
#   color: black;
# }
# #T_c7bd9_row0_col1, #T_c7bd9_row3_col1, #T_c7bd9_row6_col1, #T_c7bd9_row9_col1, #T_c7bd9_row12_col1 {
#   background-color: green;
# }
# #T_c7bd9_row0_col4 {
#   background-color: #61b061;
#   color: #f1f1f1;
# }
# #T_c7bd9_row1_col1, #T_c7bd9_row4_col1, #T_c7bd9_row7_col1, #T_c7bd9_row9_col3, #T_c7bd9_row10_col1, #T_c7bd9_row12_col3, #T_c7bd9_row15_col3, #T_c7bd9_row16_col3 {
#   background-color: red;
# }
# #T_c7bd9_row1_col4 {
#   background-color: #a2cfa2;
#   color: #000000;
# }
# #T_c7bd9_row2_col1, #T_c7bd9_row5_col1, #T_c7bd9_row8_col1, #T_c7bd9_row11_col1, #T_c7bd9_row13_col1, #T_c7bd9_row14_col1, #T_c7bd9_row15_col1, #T_c7bd9_row16_col1 {
#   background-color: blue;
# }
# #T_c7bd9_row2_col4 {
#   background-color: #b3d8b3;
#   color: #000000;
# }
# #T_c7bd9_row3_col0, #T_c7bd9_row4_col0, #T_c7bd9_row5_col0 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_c7bd9_row3_col4, #T_c7bd9_row4_col4 {
#   background-color: #41a041;
#   color: #f1f1f1;
# }
# #T_c7bd9_row5_col4 {
#   background-color: #86c286;
#   color: #000000;
# }
# #T_c7bd9_row6_col0, #T_c7bd9_row7_col0, #T_c7bd9_row8_col0 {
#   background-color: lightskyblue;
#   color: black;
# }
# #T_c7bd9_row6_col4 {
#   background-color: #349934;
#   color: #f1f1f1;
# }
# #T_c7bd9_row7_col4 {
#   background-color: #259225;
#   color: #f1f1f1;
# }
# #T_c7bd9_row8_col4 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_c7bd9_row9_col0, #T_c7bd9_row10_col0, #T_c7bd9_row11_col0 {
#   background-color: lightcoral;
#   color: black;
# }
# #T_c7bd9_row9_col4, #T_c7bd9_row12_col4 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_c7bd9_row10_col3, #T_c7bd9_row11_col3, #T_c7bd9_row13_col3, #T_c7bd9_row14_col3 {
#   background-color: orange;
# }
# #T_c7bd9_row10_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_c7bd9_row11_col4 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_c7bd9_row12_col0, #T_c7bd9_row13_col0 {
#   background-color: gold;
#   color: black;
# }
# #T_c7bd9_row13_col4, #T_c7bd9_row15_col4, #T_c7bd9_row16_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_c7bd9_row14_col0 {
#   background-color: plum;
#   color: black;
# }
# #T_c7bd9_row14_col4 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# #T_c7bd9_row15_col0 {
#   background-color: darkseagreen;
#   color: black;
# }
# #T_c7bd9_row16_col0 {
#   background-color: saphire;
#   color: black;
# }
# </style>
# <table id="T_c7bd9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7bd9_level0_col0" class="col_heading level0 col0" >parch</th>
#       <th id="T_c7bd9_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_c7bd9_level0_col2" class="col_heading level0 col2" >survived_sum</th>
#       <th id="T_c7bd9_level0_col3" class="col_heading level0 col3" >survived_count</th>
#       <th id="T_c7bd9_level0_col4" class="col_heading level0 col4" >percentage_survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7bd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7bd9_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_c7bd9_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_c7bd9_row0_col2" class="data row0 col2" >141.000000</td>
#       <td id="T_c7bd9_row0_col3" class="data row0 col3" >242</td>
#       <td id="T_c7bd9_row0_col4" class="data row0 col4" >58.264463</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7bd9_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_c7bd9_row1_col1" class="data row1 col1" >2.000000</td>
#       <td id="T_c7bd9_row1_col2" class="data row1 col2" >64.000000</td>
#       <td id="T_c7bd9_row1_col3" class="data row1 col3" >206</td>
#       <td id="T_c7bd9_row1_col4" class="data row1 col4" >31.067961</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7bd9_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_c7bd9_row2_col1" class="data row2 col1" >3.000000</td>
#       <td id="T_c7bd9_row2_col2" class="data row2 col2" >131.000000</td>
#       <td id="T_c7bd9_row2_col3" class="data row2 col3" >554</td>
#       <td id="T_c7bd9_row2_col4" class="data row2 col4" >23.646209</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7bd9_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_c7bd9_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_c7bd9_row3_col2" class="data row3 col2" >36.000000</td>
#       <td id="T_c7bd9_row3_col3" class="data row3 col3" >50</td>
#       <td id="T_c7bd9_row3_col4" class="data row3 col4" >72.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7bd9_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_c7bd9_row4_col1" class="data row4 col1" >2.000000</td>
#       <td id="T_c7bd9_row4_col2" class="data row4 col2" >31.000000</td>
#       <td id="T_c7bd9_row4_col3" class="data row4 col3" >43</td>
#       <td id="T_c7bd9_row4_col4" class="data row4 col4" >72.093023</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7bd9_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_c7bd9_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_c7bd9_row5_col2" class="data row5 col2" >33.000000</td>
#       <td id="T_c7bd9_row5_col3" class="data row5 col3" >77</td>
#       <td id="T_c7bd9_row5_col4" class="data row5 col4" >42.857143</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7bd9_row6_col0" class="data row6 col0" >2.000000</td>
#       <td id="T_c7bd9_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_c7bd9_row6_col2" class="data row6 col2" >21.000000</td>
#       <td id="T_c7bd9_row6_col3" class="data row6 col3" >27</td>
#       <td id="T_c7bd9_row6_col4" class="data row6 col4" >77.777778</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7bd9_row7_col0" class="data row7 col0" >2.000000</td>
#       <td id="T_c7bd9_row7_col1" class="data row7 col1" >2.000000</td>
#       <td id="T_c7bd9_row7_col2" class="data row7 col2" >21.000000</td>
#       <td id="T_c7bd9_row7_col3" class="data row7 col3" >25</td>
#       <td id="T_c7bd9_row7_col4" class="data row7 col4" >84.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7bd9_row8_col0" class="data row8 col0" >2.000000</td>
#       <td id="T_c7bd9_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_c7bd9_row8_col2" class="data row8 col2" >15.000000</td>
#       <td id="T_c7bd9_row8_col3" class="data row8 col3" >61</td>
#       <td id="T_c7bd9_row8_col4" class="data row8 col4" >24.590164</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7bd9_row9_col0" class="data row9 col0" >3.000000</td>
#       <td id="T_c7bd9_row9_col1" class="data row9 col1" >1.000000</td>
#       <td id="T_c7bd9_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_c7bd9_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_c7bd9_row9_col4" class="data row9 col4" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7bd9_row10_col0" class="data row10 col0" >3.000000</td>
#       <td id="T_c7bd9_row10_col1" class="data row10 col1" >2.000000</td>
#       <td id="T_c7bd9_row10_col2" class="data row10 col2" >3.000000</td>
#       <td id="T_c7bd9_row10_col3" class="data row10 col3" >3</td>
#       <td id="T_c7bd9_row10_col4" class="data row10 col4" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7bd9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7bd9_row11_col0" class="data row11 col0"

# %% [markdown]
# Wyników procentowych sans na przeżycie nie powinniśmy brać dosadnie dla pasażerów, którzy **mieli od 3 do 9 rodziców/dzieci** ze sobą na pokładzie, gdyż takich pasażerów było **stosunkowo mało**

# %% [markdown]
# #### 2. Wykres szans na przeżycie uwzględniając ilość rodziców/dzieci

# %%
sns.barplot(x="parch", y="percentage_survived", hue="pclass", data=parch_grouped_survived_df, palette="muted");
plt.title("Wykres pokazujący procentowe sznanse na przeżycie patrząc na ilość bliskich");
plt.ylabel("Sznasa na przeżycie(%)");
plt.xlabel("Ilość dzieci/rodziców jakie miał na pokładzie pasażer");

# %% [markdown]
# Możemy tu zauważyć, że wśród pasażerów z klasy drugiej, którzy mieli 2 dzieci/rodziców na pokładzie przeżyło `84%` z nich

# %% [markdown]
# ## 6. Szukamy odstających wartości

# %% [markdown]
# #### 1. Wykres pudłkowy dla wszystkich pasażerów

# %%
df.plot(kind="box");

# %% [markdown]
# Widzimy, że:
# - jest wiele odstających wartości w kolumnie age, to znaczy, że na statku były również osoby w zaawansowanym wieku,
# - są wartości odstające w koumnie sibsp i parch, znaczy, to, że na statku były roziny wielodzietne,
# - widzimy wiele wartości odstających dla kolumny fare,co oznacza, że wiele biletów na statek było znacznie droższych od normalnych biletów

# %% [markdown]
# #### 2. Wykres pudłkowy dla pasażerów klasy 3

# %%
classs_3_df.plot(kind="box");

# %% [markdown]
# Możemy zauwazyć, że wartości odstające dla pasażerów klasy 3 są podobne do wartości odstających u wszystkkich pasażerów,
# lecz możemy zauważyć, że w tej klasie nie było biletu, kktóry tak znacząco odbiegałby ceną od innych

# %% [markdown]
# #### 3. Wykres pudłkowy dla pasażerów klasy 2

# %%
classs_2_df.plot(kind="box");

# %% [markdown]
# W klasie 2 obserwujemy, że na pokładzie było lub były bardzo małe dzieci, a także nie było wiele odstających ceną od normy biletów

# %% [markdown]
# #### 4. Wykres pudłkowy dla pasażerów klasy 1

# %%
classs_1_df.plot(kind="box");

# %% [markdown]
# Niektóre ceny biletów w klasie 1 były znacznie wygórowane od innych cen biletów w tej klasie

# %% [markdown]
# ### 7. Podsumowanie

# %% [markdown]
# Podsumowując znależliśmy w danych, że:
# - na pokładzie statku było więcej mężczyzn niż kobiet
# - katastrofę przeżyło `500 osób`
# - **najwięcej osób** przeżyło z 1 klasy, a najmniej z 3
# - przeżyło **więcej** kobiet niż mężczyzn
# - kobiety **w 1 i 2** klasie miały bardzo duże na przeżycie, około `90%` niezależnie od wieku
# - w **klasie 3** szanse na przeżycie kobiet uwzględniając wiek były **znaczie mniejsze**, bo wynosiły od `55%` szans do `33%`
# - mężczyźni **patrząc na wszytskie klasy** mieli bardzo małe szanse na przeżycie, bo mniejsze niż `35%`
# - mężczyźni z **klasy 1** w wieku `0-18` przeżyli w 75% procentach, lecz wszytskich mężczyzn w tym wieku **w klasie 1** było `jedynie 8`
# - katastrofę przeżyło dość spora część pasażerów, `bo około 75%` **z klasy 1 i 2**, którzy mieli na pokładzie **1 lub 2** członków rodziny
# <!-- - w niektórych klasach wiek wpływał na szansę na uratwanie się z katastrofy
# - cena biletu niezależnie od klasy nie miała związku z szansą na przeżycie
# - jeżeli członkowie statku posiadali większe rodziny szansa na ich przeżycie malała -->
